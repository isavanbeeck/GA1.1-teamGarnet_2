# %%
def multiply(x, y):
    return x * y

print(multiply(3, 4))  # Output: 12

z = multiply(5, 6)
print(z)  # Output: 30
# Out:
# 12
# 30

# %%
def square(x):
    return multiply(x, x)

print(square(5)) # Output: 25
